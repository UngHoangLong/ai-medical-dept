# %%
# %uv pip install huggingface_hub
# Out:
# Using Python 3.12.6 environment at: /usr/local
# Audited 1 package in 11ms
# Note: you may need to restart the kernel to use updated packages.

# %%
# !hf download UngLong/openm3chest-npy-v2 --repo-type dataset --local-dir /mnt/ct-rate --token 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
# Out:
# Fetching 1743 files:   0%|                             | 0/1743 [00:00<?, ?it/s]Still waiting to acquire lock on /mnt/ct-rate/.cache/huggingface/.gitignore.lock (elapsed: 0.1 seconds)
# ...
#
# data/train/shard-00005-of-99999.parquet:   0%|      | 0.00/21.7k [00:00<?, ?B/s]
#
# data/train/shard-00006-of-99999.parquet:   0%|      | 0.00/17.0k [00:00<?, ?B/s]
#
#
# data/train/shard-00000-of-99999.parquet:   0%|      | 0.00/19.4k [00:00<?, ?B/s]
#
#
#
# data/train/shard-00004-of-99999.parquet:   0%|      | 0.00/18.4k [00:00<?, ?B/s]Downloading 'data/train/shard-00003-of-99999.parquet' to '/mnt/ct-rate/.cache/huggingface/download/data/train/IOcoI_d4bEVhmsSJBpujqIN87aA=.f8731c05bf3b6f86703ec9bc20d640ff52a3b91f9dc3da7bba1ac94dd5a4a35e.incomplete'
# ...
#
#
#
#
#
# .gitattributes: 2.50kB [00:00, 10.1MB/s]
# Download complete. Moving file to /mnt/ct-rate/.gitattributes
# Fetching 1743 files:   0%|                     | 1/1743 [00:00<09:31,  3.05it/s]
#
#
#
#
# ...
